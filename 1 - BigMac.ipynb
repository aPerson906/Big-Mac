# %% [markdown]
# # Big Mac Activities
# Let's take a look at a familiar data set (the cost of big macs around the world) and analyse it using Jupyter Notebook and Pandas. This skillset will **_directly_** link to your assessment task.
#
# Complete each activity stipulated in the comments by looking at the *even-more-python-for-beginners* provided on GitHub.
#
# ## Series
# Complete the following pandas Series following the instructions in the comments:

# %%
import pandas as pd

countries = pd.Series([
                        'Australia',
                        'Britain',
                        'New Zealand',
                        'United States'
                        ])
countries


#Create a pandas Series which contains 'Australia', 'Britain', 'New Zealand' and 'United States' and store them on separate lines in a variable, 'countries'. 
#Print the series
# Out:
# 0        Australia
# 1          Britain
# 2      New Zealand
# 3    United States
# dtype: str

# %%
#Output Britain from the list using its index
countries[1]
# Out:
# 'Britain'

# %%
#Iterate through all values in countries series using a for loop
for x in countries:
    print(x)
# Out:
# Australia
# Britain
# New Zealand
# United States

# %% [markdown]
# ## DataFrame
# Usually we work with two-dimensional arrays. We store them using **DataFrame** in pandas.
#
# ### Activity
# Let's use a DataFrame to store more meaningful values than our countries series. Let's store the following values in a Data Frame called 'big_mac':
#
# **Headings:** Country, Local Price, AUD Price
# - `'Australia', 7.45, 7.45`
# - `'Britain', 4.19, 0.0`
# - `'Japan', 450, 0.0`
# - `'New Zealand', 7.1, 0.0`
# - `'United States', 5.58, 0.0`
#
# **NOTE:** You'll need to look online at current rates to convert Britain, New Zealand, Japan and United States' local prices to AUD.

# %%
#Add a pandas DataFrame called 'big_mac' with the above values
big_mac = pd.DataFrame([
                        ['Australia', 7.45, 7.45],
                        ['Britain', 4.19, 0.0],
                        ['Japan', 450, 0.0],
                        ['New Zealand', 7.1, 0.0],
                        ['United States', 5.58, 0.0],
                        ],
                        columns = ['Country', 'Local Price', 'AUD Price']
                        )
#Print the DataFrame
big_mac
# Out:
#          Country  Local Price  AUD Price
# 0      Australia         7.45       7.45
# 1        Britain         4.19       0.00
# 2          Japan       450.00       0.00
# 3    New Zealand         7.10       0.00
# 4  United States         5.58       0.00

# %% [markdown]
# ## Examining pandas DataFrames

# %%
big_mac.head(2)
# Out:
#      Country  Local Price  AUD Price
# 0  Australia         7.45       7.45
# 1    Britain         4.19       0.00

# %%
#Print only the last four rows of the big_mac dataframe
big_mac.tail(4)
# Out:
#          Country  Local Price  AUD Price
# 1        Britain         4.19        0.0
# 2          Japan       450.00        0.0
# 3    New Zealand         7.10        0.0
# 4  United States         5.58        0.0

# %%
#Print the number of rows and columns in the big_mac dataframe
big_mac.shape
# Out:
# (5, 3)

# %%
#Print some detailed information about the big_mac dataframe
big_mac.info
# Out:
# <bound method DataFrame.info of          Country  Local Price  AUD Price
# 0      Australia         7.45       7.45
# 1        Britain         4.19       0.00
# 2          Japan       450.00       0.00
# 3    New Zealand         7.10       0.00
# 4  United States         5.58       0.00>

# %% [markdown]
# ## Querying DataFrames
# Let's explore how we request data from a pandas DataFrame.

# %%
#Request and output the 'Country' and 'AUD Price' columns from the big_mac DataFrame.
big_mac[['Country', 'AUD Price']]
# Out:
#          Country  AUD Price
# 0      Australia       7.45
# 1        Britain       0.00
# 2          Japan       0.00
# 3    New Zealand       0.00
# 4  United States       0.00

# %%
#Use iloc to request the third row, all columns
# Out:
# ---------------------------------------------------------------------------
# IndexingError                             Traceback (most recent call last)
# Cell In[230], line 2
#       1 #Use iloc to request the third row, all columns
# ----> 2 countries.iloc[0,4:]
#
# File ~\AppData\Roaming\Python\Python314\site-packages\pandas\core\indexing.py:1200, in _LocationIndexer.__getitem__(self, key)
#    1198     if self._is_scalar_access(key):
#    1199         return self.obj._get_value(*key, takeable=self._takeable)
# -> 1200     return self._getitem_tuple(key)
#    1201 else:
#    1202     # we by definition only have the 0th axis
#    1203     axis = self.axis or 0
#
# File ~\AppData\Roaming\Python\Python314\site-packages\pandas\core\indexing.py:1711, in _iLocIndexer._getitem_tuple(self, tup)
#    1710 def _getitem_tuple(self, tup: tuple):
# -> 1711     tup = self._validate_tuple_indexer(tup)
#    1712     with suppress(IndexingError):
#    1713         return self._getitem_lowerdim(tup)
#
# File ~\AppData\Roaming\Python\Python314\site-packages\pandas\core\indexing.py:989, in _LocationIndexer._validate_tuple_indexer(self, key)
#     984 @final
#     985 def _validate_tuple_indexer(self, key: tuple) -> tuple:
#     986     """
#     987     Check the key for valid keys across my indexer.
#     988     """
# --> 989     key = self._validate_key_length(key)
#     990     key = self._expand_ellipsis(key)
#     991     for i, k in enumerate(key):
#
# File ~\AppData\Roaming\Python\Python314\site-packages\pandas\core\indexing.py:1027, in _LocationIndexer._validate_key_length(self, key)
#    1025             raise IndexingError(_one_ellipsis_message)
#    1026         return self._validate_key_length(key)
# -> 1027     raise IndexingError("Too many indexers")
#    1028 return key
#
# IndexingError: Too many indexers

# %%
#Use iloc to request all rows, but just the 'Country' and 'AUD Price' columns

# %%
#Use loc to do the same thing as the previous (Country and AUD Price all rows)
